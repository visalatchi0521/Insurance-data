# %%
import pandas as pd 
import numpy as np
import seaborn as sb
import matplotlib.pyplot as plt

# %%
df=pd.read_csv("health_insurance.csv")
df.head()
# Out:
#    age     sex     bmi  children smoker     region      charges
# 0   19  female  27.900         0    yes  southwest  16884.92400
# 1   18    male  33.770         1     no  southeast   1725.55230
# 2   28    male  33.000         3     no  southeast   4449.46200
# 3   33    male  22.705         0     no  northwest  21984.47061
# 4   32    male  28.880         0     no  northwest   3866.85520

# %%
df['bmi'].shape
# Out:
# (1338,)

# %%
df['age'].shape
# Out:
# (1338,)

# %%
df.describe()
# Out:
#                age          bmi     children       charges
# count  1338.000000  1338.000000  1338.000000   1338.000000
# mean     39.207025    30.663397     1.094918  13270.422265
# std      14.049960     6.098187     1.205493  12110.011237
# min      18.000000    15.960000     0.000000   1121.873900
# 25%      27.000000    26.296250     0.000000   4740.287150
# 50%      39.000000    30.400000     1.000000   9382.033000
# 75%      51.000000    34.693750     2.000000  16639.912515
# max      64.000000    53.130000     5.000000  63770.428010

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1338 entries, 0 to 1337
# Data columns (total 7 columns):
# age         1338 non-null int64
# sex         1338 non-null object
# bmi         1338 non-null float64
# children    1338 non-null int64
# smoker      1338 non-null object
# region      1338 non-null object
# charges     1338 non-null float64
# dtypes: float64(2), int64(2), object(3)
# memory usage: 73.2+ KB

# %%
df['sex'].unique()
# Out:
# array(['female', 'male'], dtype=object)

# %%
df['smoker'].unique()
# Out:
# array(['yes', 'no'], dtype=object)

# %%
df['region'].unique()
# Out:
# array(['southwest', 'southeast', 'northwest', 'northeast'], dtype=object)

# %%
df.boxplot('charges',by='region',grid=False,figsize=(8,10))

# %%
df.boxplot('charges',by='sex',grid=False,figsize=(8,10))

# %%
sb.regplot(data=df,x='age',y='charges')

# %%
plt.scatter(data=df,x='bmi',y='charges',alpha=0.1)

# %%
g=sb.FacetGrid(data=df,col='sex')
g.map(plt.hist,'charges')

# %%
sb.lmplot(x="bmi", y="age", data=df)

# %%
plt.hist(data=df,x='children')
# Out:
# (array([574.,   0., 324.,   0., 240.,   0., 157.,   0.,  25.,  18.]),
#  array([0. , 0.5, 1. , 1.5, 2. , 2.5, 3. , 3.5, 4. , 4.5, 5. ]),
#  <a list of 10 Patch objects>)

# %%
corr=df.corr()
corr
# Out:
#                age       bmi  children   charges
# age       1.000000  0.109272  0.042469  0.299008
# bmi       0.109272  1.000000  0.012759  0.198341
# children  0.042469  0.012759  1.000000  0.067998
# charges   0.299008  0.198341  0.067998  1.000000

# %%
sb.heatmap(corr,annot=True)

# %%
df.boxplot('charges',by='smoker',grid=False,figsize=(8,10))

# %%
df.to_csv("health_insurance_2.csv")
